# %%
import numpy as np
import pandas as pd

# %%
txt = pd.read_csv('./data/미니2발표문.txt','r')
txt
# Out:
# C:\Users\admin\Anaconda3\envs\nlp\lib\site-packages\IPython\core\interactiveshell.py:3398: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                   발표문
# 0                                              안녕하세요
# 1   저희는 이륜차 사고에 대해 분석하고 그에 대한 정보를 제공하는 프로젝트를 진행하였습니다.
# 2   발표 순서는 개요, 데이터 수집 및 분석, 결과 마지막으로 장고를 보여드리며 마무리...
# 3                  저희가 많은 사고 중 이륜차를 선택한 이유는 다음과 같습니다.
# 4   코로나 이후로 배달 수요가 증가했고 이륜차 등록대수 및 사고율도 증가하였다는 기사를...
# 5                               바로 데이터에 대해 설명해드리겠습니다.
# 6            가장 먼저 조사한 것은 전국의 배달원 수와 온라인 판매량의 증감률입니다.
# 7   데이터 설명 전 온라인 판매량의 데이터를 수집한 이유는 배달 데이터가 대부분 유료로...
# 8     그래프를 보면 배달원 수와 온라인 판매량 모두 계속 증가하는 추세를 보이고 있습니다.
# 9   다음은 이륜차 등록 현황입니다. 이륜차도 17년부터 20년까지 계속해서 증가하다 2...
# 10                                     다음은 이륜차 사고입니다.
# 11   21년에 일어난 전체 교통사고 중 이륜차 사고는 전체 사고 중 31%를 차지하였습니다.
# 12  18년부터 21년 까지 월별 이륜차사고를 조사해보니 증가 추세를 보이고 있고 부상자...
# 13        다음은 이륜차 등록대수와 배달종사자수 사고건수를 모아 그래프를 그려보았습니다.
# 14  종사자수는 꾸준히 증가하는 반면 등록수와 사고수는 증가하다가 21년에 조금 감소하였...
# 15  앞에서 년도별로 확인을 하였고 더 정확한 수지를 보고싶어 월별로 전국 등록대수와 온...
# 16                    이 그래프 역시 모두 상승하는 수치를 보이고 있습니다.
# 17  사고유형을 조사해보니 이륜차대 이륜차 사고가 이륜차와 사람, 이륜차 단독 사고보다 ...
# 18                            사고에 이어 법규위반사례를 알아보겠습니다.
# 19     법규위반은 18년에서 21년 모두 신호위반보다 보호장구미착용건수가 가장 많았습니다.
# 20                     이를 바탕으로 헬멧여부에 대한 자료를 조사해보았습니다.
# 21  교통사고 사망자내 헬멧착용 여부 비율을 보니 헬멧을 쓰지않은 사람의 사망률이 높은 ...
# 22              추가로 서울 기준 요일, 시간대별 이륜차 사고수를 조사해보았습니다.
# 23  4년간 빠지지 않고 금,토가 가장많은 사고가 일어났고 18시에서 20시 사이에 가장...
# 24  다음은 서울을 기준으로 이륜차 사고가 가장많이 일어나는 지역과 구역을 히트맵과 포리...
# 25        다음은 앞서 정제한 데이터를 바탕으로 다양한 검증 및 분석을 진행해보았습니다.
# 26                    먼저 헬멧여부와 사망자율에 대해 t-검정을 해보았습니다.
# 27  귀무가설을 헬멧을 착용하면 사망 가능성이 늘어난다로 두었고 결과 p-value가 0...
# 28  다음은 년도 별 이륜차 등록수와 사고건수를 t-검정과 상관관계를 진행해보았습니다. ...
# 29  앞선 두 요소에 배달종사자수를 함께 분석해보았더니 다음과 같은 결과가 나왔습니다. ...
# 30  먼저 월별 등록대수와 사고율을 상관관계와 회귀분석을 진행하였고 양의 상관관계를 보이...
# 31                                                 >
# 32  다음은 월별 온라인 판매량과 사고율을 상관관계와 회귀분석을 진행하였고 양의 상관관계...
# 33                                                  >
# 34  월별 등록대수와 온라인 판매량 역시 같은 양의 상관관계와 0.83의 높은 상관계수를...
# 35                                                  >
# 36                                                앞선
# 37  세가지 요소가 거의 모두 양의 상관관계를 보이고 있고 특히 이륜차 등록대수와 온라인...
# 38  사고율과 온라인판매량, 사고율과 이륜차등록대수 역시 0.7이상으로 큰 관계성을 보이...
# 39         다음은 강수량과 사고의 관련성을 알아보고싶어 추가로 분석을 진행해보았습니다.
# 40                          지역을 서울과 부산으로 나누어 조사하였습니다.
# 41  먼저 서울의 결과 입니다. 서울은 강수량과 사고건수가 비슷한 그래프를 그리고 있습니...
# 42  상관관계를 분석해보니 산점도가 많이 퍼져있지만 그래도 양의 그래프를 그리고 있습니다...
# 43                                         부산의 결과입니다.
# 44  부산은 꺾은선 그래프만 봐도 강수량과 사고건수가 전혀 다른 추세를 보이고 있음을 알...
# 45       검정결과 역시 p-value가 0.365로 0.05보다 훨씬 높은 값이 나왔다.
# 46  부산과 서울을 비교해보았을때 비교적 서울이 부산보다 강수량과 사고건수가 연관이 있다...
# 47                                             결과입니다.
# 48  배달 종사자와 온라인 매출은 꾸준히 증가하나 이륜차 등록수와 사고건수는 21년 기준...
# 49  또한 헬멧 착용이 사망과 관련이 있으므로 이륜차 이용시 꼭 안전보호장구를 착용하여야...
# 50                     마지막으로 django를 보여드리고 발표 끝내겠습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import re
from PIL import Image
from os import path
from wordcloud import WordCloud

# %%
mask = np.array(Image.open('./data/사람.png'))

# %%
f = open('./data/morph.txt','r', encoding='utf8')
txt = f.readlines()
f.close()

# %%
txt
# Out:
# ['발표\n',
#  '문\n',
#  '\n',
#  '\n',
#  '안녕하세요\n',
#  '저희\n',
#  '는\n',
#  '이륜차\n',
#  '사고\n',
#  '에\n',
#  '대해\n',
#  '분석\n',
#  '하고\n',
#  '그\n',
#  '에\n',
#  '대한\n',
#  '정보\n',
#  '를\n',
#  '제공\n',
#  '하는\n',
#  '프로젝트\n',
#  '를\n',
#  '진행\n',
#  '하였습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '발표\n',
#  '순서\n',
#  '는\n',
#  '개요\n',
#  ',\n',
#  '데이터\n',
#  '수집\n',
#  '및\n',
#  '분석\n',
#  ',\n',
#  '결과\n',
#  '마지막\n',
#  '으로\n',
#  '장고\n',
#  '를\n',
#  '보여\n',
#  '드리며\n',
#  '마무리\n',
#  '하려\n',
#  '합니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '저희\n',
#  '가\n',
#  '많은\n',
#  '사고\n',
#  '중\n',
#  '이륜차\n',
#  '를\n',
#  '선택\n',
#  '한\n',
#  '이유\n',
#  '는\n',
#  '다음\n',
#  '과\n',
#  '같습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '코로나\n',
#  '이후\n',
#  '로\n',
#  '배달\n',
#  '수요\n',
#  '가\n',
#  '증가\n',
#  '했고\n',
#  '이륜차\n',
#  '등록\n',
#  '대수\n',
#  '및\n',
#  '사고\n',
#  '율도\n',
#  '증가\n',
#  '하였다는\n',
#  '기사\n',
#  '를\n',
#  '접\n',
#  '하였습니다\n',
#  '.\n',
#  '여기\n',
#  '서\n',
#  '저희\n',
#  '는\n',
#  '아마\n',
#  '음식\n',
#  '배달\n',
#  '이\n',
#  '늘면서\n',
#  '배달\n',
#  '원\n',
#  '이\n',
#  '늘\n',
#  '고\n',
#  '그로\n',
#  '인해\n',
#  '이륜차\n',
#  '등록\n',
#  '대수\n',
#  '또한\n',
#  '늘\n',
#  '지\n',
#  '않았을까\n',
#  '라고\n',
#  '생각\n',
#  '하였습니다\n',
#  '.\n',
#  '그래서\n',
#  '배달\n',
#  '과\n',
#  '이륜차\n',
#  '등록\n',
#  '대수\n',
#  '및\n',
#  '사고\n',
#  '율\n',
#  '증가\n',
#  '가\n',
#  '관련\n',
#  '이\n',
#  '있는지\n',
#  '궁금하였고\n',
#  '또\n',
#  '이륜차\n',
#  '사고\n',
#  '에\n',
#  '대한\n',
#  '데이터\n',
#  '를\n',
#  '조사\n',
#  '하여\n',
#  '이륜차\n',
#  '운전자\n',
#  '들\n',
#  '또는\n',
#  '이를\n',
#  '궁금해하는\n',
#  '사람\n',
#  '들\n',
#  '에게\n',
#  '교통사고\n',
#  '관련\n',
#  '정보\n',
#  '를\n',
#  '제공\n',
#  '해주는\n',
#  '웹\n',
#  '을\n',
#  '구현\n',
#  '해보면\n',
#  '좋을\n',
#  '것\n',
#  '같아\n',
#  '이\n',
#  '주제\n',
#  '를\n',
#  '선정\n',
#  '하게\n',
#  '되었습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '바로\n',
#  '데이터\n',
#  '에\n',
#  '대해\n',
#  '설명\n',
#  '해드리겠습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '가장\n',
#  '먼저\n',
#  '조사\n',
#  '한\n',
#  '것\n',
#  '은\n',
#  '전국\n',
#  '의\n',
#  '배달\n',
#  '원\n',
#  '수\n',
#  '와\n',
#  '온라인\n',
#  '판매량\n',
#  '의\n',
#  '증감\n',
#  '률\n',
#  '입니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '데이터\n',
#  '설명\n',
#  '전\n',
#  '온라인\n',
#  '판매량\n',
#  '의\n',
#  '데이터\n',
#  '를\n',
#  '수집\n',
#  '한\n',
#  '이유\n',
#  '는\n',
#  '배달\n',
#  '데이터\n',
#  '가\n',
#  '대부분\n',
#  '유료\n',
#  '로\n',
#  '확인\n',
#  '되어\n',
#  '조사\n',
#  '할\n',
#  '때\n',
#  '관련\n',
#  '기사\n',
#  '에서\n',
#  '배달\n',
#  '의\n',
#  '증가\n',
#  '현황\n',
#  '을\n',
#  '온라인\n',
#  '매출\n',
#  '현황\n',
#  '으로\n',
#  '작성\n',
#  '한\n',
#  '기사\n',
#  '를\n',
#  '참고\n',
#  '하여\n',
#  '해당\n',
#  '데이터\n',
#  '를\n',
#  '사용\n',
#  '하게\n',
#  '되었습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '그래프\n',
#  '를\n',
#  '보면\n',
#  '배달\n',
#  '원\n',
#  '수\n',
#  '와\n',
#  '온라인\n',
#  '판매량\n',
#  '모두\n',
#  '계속\n',
#  '증가\n',
#  '하는\n',
#  '추세\n',
#  '를\n',
#  '보이\n',
#  '고\n',
#  '있습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '다음\n',
#  '은\n',
#  '이륜차\n',
#  '등록\n',
#  '현황\n',
#  '입니다\n',
#  '.\n',
#  '이륜차\n',
#  '도\n',
#  '17년\n',
#  '부터\n',
#  '20년\n',
#  '까지\n',
#  '계속\n',
#  '해서\n',
#  '증가\n',
#  '하다\n',
#  '21년\n',
#  '에\n',
#  '감소\n',
#  '한\n',
#  '것\n',
#  '을\n',
#  '알\n',
#  '수\n',
#  '있습니다\n',
#  '.\n',
#  '감소\n',
#  '의\n',
#  '원인\n',
#  '을\n',
#  '조사\n',
#  '해보니\n',
#  '아마\n',
#  '불법\n',
#  '이륜차\n',
#  '단속\n',
#  '으로\n',
#  '인한\n',
#  '영향\n',
#  '을\n',
#  '받은\n',
#  '것\n',
#  '같습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '다음\n',
#  '은\n',
#  '이륜차\n',
#  '사고\n',
#  '입니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '21년\n',
#  '에\n',
#  '일어난\n',
#  '전체\n',
#  '교통사고\n',
#  '중\n',
#  '이륜차\n',
#  '사고\n',
#  '는\n',
#  '전체\n',
#  '사고\n',
#  '중\n',
#  '31%\n',
#  '를\n',
#  '차지\n',
#  '하였습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '18년\n',
#  '부터\n',
#  '21년\n',
#  '까지\n',
#  '월별\n',
#  '이륜차\n',
#  '사고\n',
#  '를\n',
#  '조사\n',
#  '해보니\n',
#  '증가\n',
#  '추세\n',
#  '를\n',
#  '보이\n',
#  '고\n',
#  '있고\n',
#  '부상\n',
#  '자\n',
#  '역시\n',
#  '사고건\n',
#  '수\n',
#  '와\n',
#  '함께\n',
#  '비슷한\n',
#  '수치\n',
#  '를\n',
#  '보이\n',
#  '고\n',
#  '있습니다\n',
#  '.\n',
#  '왼쪽\n',
#  '이\n',
#  '이륜차\n',
#  '사고\n',
#  '율\n',
#  '오른쪽\n',
#  '이\n',
#  '사고건\n',
#  '수\n',
#  '와\n',
#  '부상\n',
#  '자\n',
#  ',\n',
#  '사망자\n',
#  '그래프\n',
#  '입니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '다음\n',
#  '은\n',
#  '이륜차\n',
#  '등록\n',
#  '대수\n',
#  '와\n',
#  '배달\n',
#  '종사\n',
#  '자수\n',
#  '사고건\n',
#  '수\n',
#  '를\n',
#  '모아\n',
#  '그래프\n',
#  '를\n',
#  '그려\n',
#  '보았습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '종사\n',
#  '자수\n',
#  '는\n',
#  '꾸준히\n',
#  '증가\n',
#  '하는\n',
#  '반면\n',
#  '등록\n',
#  '수\n',
#  '와\n',
#  '사\n',
#  '고수\n',
#  '는\n',
#  '증가\n',
#  '하다가\n',
#  '21년\n',
#  '에\n',
#  '조금\n',
#  '감소\n',
#  '하였습니다\n',
#  '.\n',
#  '이는\n',
#  '아마\n',
#  '이전\n',
#  '에\n',
#  '말씀드린\n',
#  '불법\n',
#  '이륜차\n',
#  '단속\n',
#  '영향\n',
#  '을\n',
#  '받은\n',
#  '것\n',
#  '같습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '앞\n',
#  '에서\n',
#  '년도\n',
#  '별로\n',
#  '확인\n',
#  '을\n',
#  '하였고\n',
#  '더\n',
#  '정확한\n',
#  '수지\n',
#  '를\n',
#  '보고싶어\n',
#  '월\n',
#  '별로\n',
#  '전국\n',
#  '등록\n',
#  '대수\n',
#  '와\n',
#  '온라인\n',
#  '판매량\n',
#  '과\n',
#  '사고\n',
#  '율\n',
#  '을\n',
#  '확인\n',
#  '하였습니다\n',
#  '.\n',
#  '배달\n',
#  '종사\n',
#  '자수\n',
#  '가\n',
#  '월\n',
#  '별로\n',
#  '제공\n',
#  '되는\n',
#  '데이터\n',
#  '가\n',
#  '없어\n',
#  '온라인\n',
#  '판매량\n',
#  '으로\n',
#  '대체\n',
#  '하였습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '이\n',
#  '그래프\n',
#  '역시\n',
#  '모두\n',
#  '상승\n',
#  '하는\n',
#  '수치\n',
#  '를\n',
#  '보이\n',
#  '고\n',
#  '있습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '사\n',
#  '고유\n',
#  '형\n',
#  '을\n',
#  '조사\n',
#  '해보니\n',
#  '이륜차\n',
#  '대\n',
#  '이륜차\n',
#  '사고\n',
#  '가\n',
#  '이륜차\n',
#  '와\n',
#  '사람\n',
#  ',\n',
#  '이륜차\n',
#  '단독\n',
#  '사고\n',
#  '보다\n',
#  '눈\n',
#  '에\n',
#  '띄게\n',
#  '많은\n',
#  '건수\n',
#  '를\n',
#  '차지\n',
#  '하고\n',
#  '있는\n',
#  '것\n',
#  '을\n',
#  '확인\n',
#  '할\n',
#  '수\n',
#  '있습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '사고\n',
#  '에\n',
#  '이어\n',
#  '법규\n',
#  '위반\n',
#  '사례\n',
#  '를\n',
#  '알아보겠습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '법규\n',
#  '위반\n',
#  '은\n',
#  '18년\n',
#  '에서\n',
#  '21년\n',
#  '모두\n',
#  '신호\n',
#  '위반\n',
#  '보다\n',
#  '보호\n',
#  '장\n',
#  '구\n',
#  '미착\n',
#  '용건\n',
#  '수가\n',
#  '가장\n',
#  '많았습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '이를\n',
#  '바탕\n',
#  '으로\n',
#  '헬멧\n',
#  '여부\n',
#  '에\n',
#  '대한\n',
#  '자료\n',
#  '를\n',
#  '조사\n',
#  '해보았습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '교통사고\n',
#  '사망자\n',
#  '내\n',
#  '헬멧\n',
#  '착용\n',
#  '여부\n',
#  '비율\n',
#  '을\n',
#  '보니\n',
#  '헬멧\n',
#  '을\n',
#  '쓰지\n',
#  '않은\n',
#  '사람\n',
#  '의\n',
#  '사망률\n',
#  '이\n',
#  '높은\n',
#  '것\n',
#  '을\n',
#  '확인\n',
#  '하였습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '추가\n',
#  '로\n',
#  '서울\n',
#  '기준\n',
#  '요일\n',
#  ',\n',
#  '시간\n',
#  '대별\n',
#  '이륜차\n',
#  '사\n',
#  '고수\n',
#  '를\n',
#  '조사\n',
#  '해보았습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '4년\n',
#  '간\n',
#  '빠지지\n',
#  '않고\n',
#  '금\n',
#  ',\n',
#  '토\n',
#  '가\n',
#  '가장\n',
#  '많은\n',
#  '사고\n',
#  '가\n',
#  '일어났고\n',
#  '18시\n',
#  '에서\n',
#  '20시\n',
#  '사이\n',
#  '에\n',
#  '가장\n',
#  '많은\n',
#  '사고\n',
#  '가\n',
#  '일어났\n',
#  '습\n',
#  '니\n',
#  '디\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '다음\n',
#  '은\n',
#  '서울\n',
#  '을\n',
#  '기준\n',
#  '으로\n',
#  '이륜차\n',
#  '사고\n',
#  '가\n',
#  '가장\n',
#  '많이\n',
#  '일어나는\n',
#  '지역\n',
#  '과\n',
#  '구역\n',
#  '을\n',
#  '히트맵\n',
#  '과\n',
#  '포리\n',
#  '움\n',
#  '으로\n',
#  '구현\n',
#  '해보았습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '다음\n',
#  '은\n',
#  '앞서\n',
#  '정제\n',
#  '한\n',
#  '데이터\n',
#  '를\n',
#  '바탕\n',
#  '으로\n',
#  '다양한\n',
#  '검증\n',
#  '및\n',
#  '분석\n',
#  '을\n',
#  '진행\n',
#  '해보았습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '먼저\n',
#  '헬멧\n',
#  '여부\n',
#  '와\n',
#  '사망\n',
#  '자율\n',
#  '에\n',
#  '대해\n',
#  't\n',
#  '-\n',
#  '검정\n',
#  '을\n',
#  '해보았습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '귀무가설\n',
#  '을\n',
#  '헬멧\n',
#  '을\n',
#  '착용\n',
#  '하면\n',
#  '사망\n',
#  '가능성\n',
#  '이\n',
#  '늘어난다로\n',
#  '두었고\n',
#  '결과\n',
#  'p\n',
#  '-\n',
#  'value\n',
#  '가\n',
#  '0.002\n',
#  '로\n',
#  '0.05\n',
#  '보다\n',
#  '낮으므로\n',
#  '귀무가설\n',
#  '이\n',
#  '기각\n',
#  '되고\n',
#  '헬멧\n',
#  '이\n',
#  '사망\n',
#  '에\n',
#  '연관\n',
#  '이\n',
#  '있고\n',
#  '미착\n',
#  '용시\n',
#  '사망\n',
#  '가능성\n',
#  '이\n',
#  '높다고\n',
#  '볼\n',
#  '수\n',
#  '있습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '다음\n',
#  '은\n',
#  '년도\n',
#  '별\n',
#  '이륜차\n',
#  '등록\n',
#  '수\n',
#  '와\n',
#  '사고건\n',
#  '수\n',
#  '를\n',
#  't\n',
#  '-\n',
#  '검정\n',
#  '과\n',
#  '상관관계\n',
#  '를\n',
#  '진행\n',
#  '해보았습니다\n',
#  '.\n',
#  'p\n',
#  '-\n',
#  'value\n',
#  '가\n',
#  '0.05\n',
#  '보다\n',
#  '낮으므로\n',
#  '이륜차\n',
#  '등록\n',
#  '수\n',
#  '와\n',
#  '사고건\n',
#  '수\n',
#  '는\n',
#  '관계\n',
#  '가\n',
#  '있는\n',
#  '것\n',
#  '으로\n',
#  '확인\n',
#  '하였고\n',
#  '상관관계\n',
#  '분석\n',
#  '을\n',
#  '통해\n',
#  '같이\n',
#  '증가\n',
#  '하는\n',
#  '것\n',
#  '을\n',
#  '알\n',
#  '수\n',
#  '있습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '앞선\n',
#  '두\n',
#  '요소\n',
#  '에\n',
#  '배달\n',
#  '종사\n',
#  '자수\n',
#  '를\n',
#  '함께\n',
#  '분석\n',
#  '해보았더니\n',
#  '다음\n',
#  '과\n',
#  '같은\n',
#  '결과\n',
#  '가\n',
#  '나왔습니다\n',
#  '.\n',
#  '히트맵\n',
#  '을\n',
#  '보시\n',
#  '면\n',
#  '이륜차\n',
#  '등록\n',
#  '수\n',
#  '와\n',
#  '사고건\n',
#  '수\n',
#  '는\n',
#  '0.65\n',
#  ',\n',
#  '종사\n',
#  '자수\n',
#  '와\n',
#  '사고건\n',
#  '수\n',
#  '는\n',
#  '0.63\n',
#  '의\n',
#  '상관\n',
#  '계수\n',
#  '가\n',
#  '나왔지만\n',
#  '분석\n',
#  '결과\n',
#  '가\n',
#  '아쉬어\n',
#  '이전\n',
#  '에\n',
#  '진행\n',
#  '한\n',
#  '월\n',
#  '별로\n',
#  '분석\n',
#  '을\n',
#  '재\n',
#  '진행\n',
#  '해보았습니다\n',
#  '.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '먼저\n',
#  '월별\n',
#  '등록\n',
#  '대수\n',
#  '와\n',
#  '사고\n',
#  '율\n',
#  '을\n',
#  '상관관계\n',
#  '와\n',
#  '회귀분석\n',
#  '을\n',
#  '진행\n',
#  '하였고\n',
#  '양\n',
#  '의\n',
#  '상관관계\n',
#  '를\n',
#  '보이\n',
#  '며\n',
#  '회귀분석\n',
#  '결과\n',
#  '는\n',
#  '다음\n',
#  '과\n',
#  '같습니다\n',
#  '.\n',
#  '>\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '다음\n',
#  '은\n',
#  '월별\n',
#  '온라인\n',
#  '판매량\n',
#  '과\n',
#  '사고\n',
#  '율\n',
#  '을\n',
#  '상관관계\n',
#  '와\n',
#  '회귀분석\n',
#  '을\n',
#  '진행\n',
#  '하였고\n',
#  '양\n',
#  '의\n',
#  '상관관계\n',
#  '를\n',
#  '보이\n',
#  '며\n',
#  '0.72\n',
#  '의\n',
#  '높은\n',
#  '상관\n',
#  '계수\n',
#  '를\n',
#  '보이\n',
#  '고\n',
#  '있습니다\n',
#  '.\n',
#  '회귀분석\n',
#  '결과\n',
#  '는\n',
#  '다음\n',
#  '과\n',
#  '같습니다\n',
#  '.\n',
#  '>\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '월별\n',
#  '등록\n',
#  '대수\n',
#  '와\n',
#  ...]

# %%
# 줄바꾸기 지우기
new_txt = []
for i in txt:
    new_txt.append(i.replace('\n',''))

# %%
new_txt
# Out:
# ['발표',
#  '문',
#  '',
#  '',
#  '안녕하세요',
#  '저희',
#  '는',
#  '이륜차',
#  '사고',
#  '에',
#  '대해',
#  '분석',
#  '하고',
#  '그',
#  '에',
#  '대한',
#  '정보',
#  '를',
#  '제공',
#  '하는',
#  '프로젝트',
#  '를',
#  '진행',
#  '하였습니다',
#  '.',
#  '',
#  '',
#  '발표',
#  '순서',
#  '는',
#  '개요',
#  ',',
#  '데이터',
#  '수집',
#  '및',
#  '분석',
#  ',',
#  '결과',
#  '마지막',
#  '으로',
#  '장고',
#  '를',
#  '보여',
#  '드리며',
#  '마무리',
#  '하려',
#  '합니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '저희',
#  '가',
#  '많은',
#  '사고',
#  '중',
#  '이륜차',
#  '를',
#  '선택',
#  '한',
#  '이유',
#  '는',
#  '다음',
#  '과',
#  '같습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '코로나',
#  '이후',
#  '로',
#  '배달',
#  '수요',
#  '가',
#  '증가',
#  '했고',
#  '이륜차',
#  '등록',
#  '대수',
#  '및',
#  '사고',
#  '율도',
#  '증가',
#  '하였다는',
#  '기사',
#  '를',
#  '접',
#  '하였습니다',
#  '.',
#  '여기',
#  '서',
#  '저희',
#  '는',
#  '아마',
#  '음식',
#  '배달',
#  '이',
#  '늘면서',
#  '배달',
#  '원',
#  '이',
#  '늘',
#  '고',
#  '그로',
#  '인해',
#  '이륜차',
#  '등록',
#  '대수',
#  '또한',
#  '늘',
#  '지',
#  '않았을까',
#  '라고',
#  '생각',
#  '하였습니다',
#  '.',
#  '그래서',
#  '배달',
#  '과',
#  '이륜차',
#  '등록',
#  '대수',
#  '및',
#  '사고',
#  '율',
#  '증가',
#  '가',
#  '관련',
#  '이',
#  '있는지',
#  '궁금하였고',
#  '또',
#  '이륜차',
#  '사고',
#  '에',
#  '대한',
#  '데이터',
#  '를',
#  '조사',
#  '하여',
#  '이륜차',
#  '운전자',
#  '들',
#  '또는',
#  '이를',
#  '궁금해하는',
#  '사람',
#  '들',
#  '에게',
#  '교통사고',
#  '관련',
#  '정보',
#  '를',
#  '제공',
#  '해주는',
#  '웹',
#  '을',
#  '구현',
#  '해보면',
#  '좋을',
#  '것',
#  '같아',
#  '이',
#  '주제',
#  '를',
#  '선정',
#  '하게',
#  '되었습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '바로',
#  '데이터',
#  '에',
#  '대해',
#  '설명',
#  '해드리겠습니다',
#  '.',
#  '',
#  '',
#  '가장',
#  '먼저',
#  '조사',
#  '한',
#  '것',
#  '은',
#  '전국',
#  '의',
#  '배달',
#  '원',
#  '수',
#  '와',
#  '온라인',
#  '판매량',
#  '의',
#  '증감',
#  '률',
#  '입니다',
#  '.',
#  '',
#  '',
#  '데이터',
#  '설명',
#  '전',
#  '온라인',
#  '판매량',
#  '의',
#  '데이터',
#  '를',
#  '수집',
#  '한',
#  '이유',
#  '는',
#  '배달',
#  '데이터',
#  '가',
#  '대부분',
#  '유료',
#  '로',
#  '확인',
#  '되어',
#  '조사',
#  '할',
#  '때',
#  '관련',
#  '기사',
#  '에서',
#  '배달',
#  '의',
#  '증가',
#  '현황',
#  '을',
#  '온라인',
#  '매출',
#  '현황',
#  '으로',
#  '작성',
#  '한',
#  '기사',
#  '를',
#  '참고',
#  '하여',
#  '해당',
#  '데이터',
#  '를',
#  '사용',
#  '하게',
#  '되었습니다',
#  '.',
#  '',
#  '',
#  '그래프',
#  '를',
#  '보면',
#  '배달',
#  '원',
#  '수',
#  '와',
#  '온라인',
#  '판매량',
#  '모두',
#  '계속',
#  '증가',
#  '하는',
#  '추세',
#  '를',
#  '보이',
#  '고',
#  '있습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '다음',
#  '은',
#  '이륜차',
#  '등록',
#  '현황',
#  '입니다',
#  '.',
#  '이륜차',
#  '도',
#  '17년',
#  '부터',
#  '20년',
#  '까지',
#  '계속',
#  '해서',
#  '증가',
#  '하다',
#  '21년',
#  '에',
#  '감소',
#  '한',
#  '것',
#  '을',
#  '알',
#  '수',
#  '있습니다',
#  '.',
#  '감소',
#  '의',
#  '원인',
#  '을',
#  '조사',
#  '해보니',
#  '아마',
#  '불법',
#  '이륜차',
#  '단속',
#  '으로',
#  '인한',
#  '영향',
#  '을',
#  '받은',
#  '것',
#  '같습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '다음',
#  '은',
#  '이륜차',
#  '사고',
#  '입니다',
#  '.',
#  '',
#  '',
#  '21년',
#  '에',
#  '일어난',
#  '전체',
#  '교통사고',
#  '중',
#  '이륜차',
#  '사고',
#  '는',
#  '전체',
#  '사고',
#  '중',
#  '31%',
#  '를',
#  '차지',
#  '하였습니다',
#  '.',
#  '',
#  '',
#  '18년',
#  '부터',
#  '21년',
#  '까지',
#  '월별',
#  '이륜차',
#  '사고',
#  '를',
#  '조사',
#  '해보니',
#  '증가',
#  '추세',
#  '를',
#  '보이',
#  '고',
#  '있고',
#  '부상',
#  '자',
#  '역시',
#  '사고건',
#  '수',
#  '와',
#  '함께',
#  '비슷한',
#  '수치',
#  '를',
#  '보이',
#  '고',
#  '있습니다',
#  '.',
#  '왼쪽',
#  '이',
#  '이륜차',
#  '사고',
#  '율',
#  '오른쪽',
#  '이',
#  '사고건',
#  '수',
#  '와',
#  '부상',
#  '자',
#  ',',
#  '사망자',
#  '그래프',
#  '입니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '다음',
#  '은',
#  '이륜차',
#  '등록',
#  '대수',
#  '와',
#  '배달',
#  '종사',
#  '자수',
#  '사고건',
#  '수',
#  '를',
#  '모아',
#  '그래프',
#  '를',
#  '그려',
#  '보았습니다',
#  '.',
#  '',
#  '',
#  '종사',
#  '자수',
#  '는',
#  '꾸준히',
#  '증가',
#  '하는',
#  '반면',
#  '등록',
#  '수',
#  '와',
#  '사',
#  '고수',
#  '는',
#  '증가',
#  '하다가',
#  '21년',
#  '에',
#  '조금',
#  '감소',
#  '하였습니다',
#  '.',
#  '이는',
#  '아마',
#  '이전',
#  '에',
#  '말씀드린',
#  '불법',
#  '이륜차',
#  '단속',
#  '영향',
#  '을',
#  '받은',
#  '것',
#  '같습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '앞',
#  '에서',
#  '년도',
#  '별로',
#  '확인',
#  '을',
#  '하였고',
#  '더',
#  '정확한',
#  '수지',
#  '를',
#  '보고싶어',
#  '월',
#  '별로',
#  '전국',
#  '등록',
#  '대수',
#  '와',
#  '온라인',
#  '판매량',
#  '과',
#  '사고',
#  '율',
#  '을',
#  '확인',
#  '하였습니다',
#  '.',
#  '배달',
#  '종사',
#  '자수',
#  '가',
#  '월',
#  '별로',
#  '제공',
#  '되는',
#  '데이터',
#  '가',
#  '없어',
#  '온라인',
#  '판매량',
#  '으로',
#  '대체',
#  '하였습니다',
#  '.',
#  '',
#  '',
#  '이',
#  '그래프',
#  '역시',
#  '모두',
#  '상승',
#  '하는',
#  '수치',
#  '를',
#  '보이',
#  '고',
#  '있습니다',
#  '.',
#  '',
#  '',
#  '사',
#  '고유',
#  '형',
#  '을',
#  '조사',
#  '해보니',
#  '이륜차',
#  '대',
#  '이륜차',
#  '사고',
#  '가',
#  '이륜차',
#  '와',
#  '사람',
#  ',',
#  '이륜차',
#  '단독',
#  '사고',
#  '보다',
#  '눈',
#  '에',
#  '띄게',
#  '많은',
#  '건수',
#  '를',
#  '차지',
#  '하고',
#  '있는',
#  '것',
#  '을',
#  '확인',
#  '할',
#  '수',
#  '있습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '사고',
#  '에',
#  '이어',
#  '법규',
#  '위반',
#  '사례',
#  '를',
#  '알아보겠습니다',
#  '.',
#  '',
#  '',
#  '법규',
#  '위반',
#  '은',
#  '18년',
#  '에서',
#  '21년',
#  '모두',
#  '신호',
#  '위반',
#  '보다',
#  '보호',
#  '장',
#  '구',
#  '미착',
#  '용건',
#  '수가',
#  '가장',
#  '많았습니다',
#  '.',
#  '',
#  '',
#  '이를',
#  '바탕',
#  '으로',
#  '헬멧',
#  '여부',
#  '에',
#  '대한',
#  '자료',
#  '를',
#  '조사',
#  '해보았습니다',
#  '.',
#  '',
#  '',
#  '교통사고',
#  '사망자',
#  '내',
#  '헬멧',
#  '착용',
#  '여부',
#  '비율',
#  '을',
#  '보니',
#  '헬멧',
#  '을',
#  '쓰지',
#  '않은',
#  '사람',
#  '의',
#  '사망률',
#  '이',
#  '높은',
#  '것',
#  '을',
#  '확인',
#  '하였습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '추가',
#  '로',
#  '서울',
#  '기준',
#  '요일',
#  ',',
#  '시간',
#  '대별',
#  '이륜차',
#  '사',
#  '고수',
#  '를',
#  '조사',
#  '해보았습니다',
#  '.',
#  '',
#  '',
#  '4년',
#  '간',
#  '빠지지',
#  '않고',
#  '금',
#  ',',
#  '토',
#  '가',
#  '가장',
#  '많은',
#  '사고',
#  '가',
#  '일어났고',
#  '18시',
#  '에서',
#  '20시',
#  '사이',
#  '에',
#  '가장',
#  '많은',
#  '사고',
#  '가',
#  '일어났',
#  '습',
#  '니',
#  '디',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '다음',
#  '은',
#  '서울',
#  '을',
#  '기준',
#  '으로',
#  '이륜차',
#  '사고',
#  '가',
#  '가장',
#  '많이',
#  '일어나는',
#  '지역',
#  '과',
#  '구역',
#  '을',
#  '히트맵',
#  '과',
#  '포리',
#  '움',
#  '으로',
#  '구현',
#  '해보았습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '다음',
#  '은',
#  '앞서',
#  '정제',
#  '한',
#  '데이터',
#  '를',
#  '바탕',
#  '으로',
#  '다양한',
#  '검증',
#  '및',
#  '분석',
#  '을',
#  '진행',
#  '해보았습니다',
#  '.',
#  '',
#  '',
#  '먼저',
#  '헬멧',
#  '여부',
#  '와',
#  '사망',
#  '자율',
#  '에',
#  '대해',
#  't',
#  '-',
#  '검정',
#  '을',
#  '해보았습니다',
#  '.',
#  '',
#  '',
#  '귀무가설',
#  '을',
#  '헬멧',
#  '을',
#  '착용',
#  '하면',
#  '사망',
#  '가능성',
#  '이',
#  '늘어난다로',
#  '두었고',
#  '결과',
#  'p',
#  '-',
#  'value',
#  '가',
#  '0.002',
#  '로',
#  '0.05',
#  '보다',
#  '낮으므로',
#  '귀무가설',
#  '이',
#  '기각',
#  '되고',
#  '헬멧',
#  '이',
#  '사망',
#  '에',
#  '연관',
#  '이',
#  '있고',
#  '미착',
#  '용시',
#  '사망',
#  '가능성',
#  '이',
#  '높다고',
#  '볼',
#  '수',
#  '있습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '다음',
#  '은',
#  '년도',
#  '별',
#  '이륜차',
#  '등록',
#  '수',
#  '와',
#  '사고건',
#  '수',
#  '를',
#  't',
#  '-',
#  '검정',
#  '과',
#  '상관관계',
#  '를',
#  '진행',
#  '해보았습니다',
#  '.',
#  'p',
#  '-',
#  'value',
#  '가',
#  '0.05',
#  '보다',
#  '낮으므로',
#  '이륜차',
#  '등록',
#  '수',
#  '와',
#  '사고건',
#  '수',
#  '는',
#  '관계',
#  '가',
#  '있는',
#  '것',
#  '으로',
#  '확인',
#  '하였고',
#  '상관관계',
#  '분석',
#  '을',
#  '통해',
#  '같이',
#  '증가',
#  '하는',
#  '것',
#  '을',
#  '알',
#  '수',
#  '있습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '앞선',
#  '두',
#  '요소',
#  '에',
#  '배달',
#  '종사',
#  '자수',
#  '를',
#  '함께',
#  '분석',
#  '해보았더니',
#  '다음',
#  '과',
#  '같은',
#  '결과',
#  '가',
#  '나왔습니다',
#  '.',
#  '히트맵',
#  '을',
#  '보시',
#  '면',
#  '이륜차',
#  '등록',
#  '수',
#  '와',
#  '사고건',
#  '수',
#  '는',
#  '0.65',
#  ',',
#  '종사',
#  '자수',
#  '와',
#  '사고건',
#  '수',
#  '는',
#  '0.63',
#  '의',
#  '상관',
#  '계수',
#  '가',
#  '나왔지만',
#  '분석',
#  '결과',
#  '가',
#  '아쉬어',
#  '이전',
#  '에',
#  '진행',
#  '한',
#  '월',
#  '별로',
#  '분석',
#  '을',
#  '재',
#  '진행',
#  '해보았습니다',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '먼저',
#  '월별',
#  '등록',
#  '대수',
#  '와',
#  '사고',
#  '율',
#  '을',
#  '상관관계',
#  '와',
#  '회귀분석',
#  '을',
#  '진행',
#  '하였고',
#  '양',
#  '의',
#  '상관관계',
#  '를',
#  '보이',
#  '며',
#  '회귀분석',
#  '결과',
#  '는',
#  '다음',
#  '과',
#  '같습니다',
#  '.',
#  '>',
#  '',
#  '',
#  '',
#  '',
#  '다음',
#  '은',
#  '월별',
#  '온라인',
#  '판매량',
#  '과',
#  '사고',
#  '율',
#  '을',
#  '상관관계',
#  '와',
#  '회귀분석',
#  '을',
#  '진행',
#  '하였고',
#  '양',
#  '의',
#  '상관관계',
#  '를',
#  '보이',
#  '며',
#  '0.72',
#  '의',
#  '높은',
#  '상관',
#  '계수',
#  '를',
#  '보이',
#  '고',
#  '있습니다',
#  '.',
#  '회귀분석',
#  '결과',
#  '는',
#  '다음',
#  '과',
#  '같습니다',
#  '.',
#  '>',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '월별',
#  '등록',
#  '대수',
#  '와',
#  ...]

# %%
str_txt = ''
for i in new_txt:
    str_txt = str_txt + i + ' '

# %%
str_txt
# Out:
# '발표 문   안녕하세요 저희 는 이륜차 사고 에 대해 분석 하고 그 에 대한 정보 를 제공 하는 프로젝트 를 진행 하였습니다 .   발표 순서 는 개요 , 데이터 수집 및 분석 , 결과 마지막 으로 장고 를 보여 드리며 마무리 하려 합니다 .     저희 가 많은 사고 중 이륜차 를 선택 한 이유 는 다음 과 같습니다 .     코로나 이후 로 배달 수요 가 증가 했고 이륜차 등록 대수 및 사고 율도 증가 하였다는 기사 를 접 하였습니다 . 여기 서 저희 는 아마 음식 배달 이 늘면서 배달 원 이 늘 고 그로 인해 이륜차 등록 대수 또한 늘 지 않았을까 라고 생각 하였습니다 . 그래서 배달 과 이륜차 등록 대수 및 사고 율 증가 가 관련 이 있는지 궁금하였고 또 이륜차 사고 에 대한 데이터 를 조사 하여 이륜차 운전자 들 또는 이를 궁금해하는 사람 들 에게 교통사고 관련 정보 를 제공 해주는 웹 을 구현 해보면 좋을 것 같아 이 주제 를 선정 하게 되었습니다 .     바로 데이터 에 대해 설명 해드리겠습니다 .   가장 먼저 조사 한 것 은 전국 의 배달 원 수 와 온라인 판매량 의 증감 률 입니다 .   데이터 설명 전 온라인 판매량 의 데이터 를 수집 한 이유 는 배달 데이터 가 대부분 유료 로 확인 되어 조사 할 때 관련 기사 에서 배달 의 증가 현황 을 온라인 매출 현황 으로 작성 한 기사 를 참고 하여 해당 데이터 를 사용 하게 되었습니다 .   그래프 를 보면 배달 원 수 와 온라인 판매량 모두 계속 증가 하는 추세 를 보이 고 있습니다 .     다음 은 이륜차 등록 현황 입니다 . 이륜차 도 17년 부터 20년 까지 계속 해서 증가 하다 21년 에 감소 한 것 을 알 수 있습니다 . 감소 의 원인 을 조사 해보니 아마 불법 이륜차 단속 으로 인한 영향 을 받은 것 같습니다 .     다음 은 이륜차 사고 입니다 .   21년 에 일어난 전체 교통사고 중 이륜차 사고 는 전체 사고 중 31% 를 차지 하였습니다 .   18년 부터 21년 까지 월별 이륜차 사고 를 조사 해보니 증가 추세 를 보이 고 있고 부상 자 역시 사고건 수 와 함께 비슷한 수치 를 보이 고 있습니다 . 왼쪽 이 이륜차 사고 율 오른쪽 이 사고건 수 와 부상 자 , 사망자 그래프 입니다 .     다음 은 이륜차 등록 대수 와 배달 종사 자수 사고건 수 를 모아 그래프 를 그려 보았습니다 .   종사 자수 는 꾸준히 증가 하는 반면 등록 수 와 사 고수 는 증가 하다가 21년 에 조금 감소 하였습니다 . 이는 아마 이전 에 말씀드린 불법 이륜차 단속 영향 을 받은 것 같습니다 .     앞 에서 년도 별로 확인 을 하였고 더 정확한 수지 를 보고싶어 월 별로 전국 등록 대수 와 온라인 판매량 과 사고 율 을 확인 하였습니다 . 배달 종사 자수 가 월 별로 제공 되는 데이터 가 없어 온라인 판매량 으로 대체 하였습니다 .   이 그래프 역시 모두 상승 하는 수치 를 보이 고 있습니다 .   사 고유 형 을 조사 해보니 이륜차 대 이륜차 사고 가 이륜차 와 사람 , 이륜차 단독 사고 보다 눈 에 띄게 많은 건수 를 차지 하고 있는 것 을 확인 할 수 있습니다 .     사고 에 이어 법규 위반 사례 를 알아보겠습니다 .   법규 위반 은 18년 에서 21년 모두 신호 위반 보다 보호 장 구 미착 용건 수가 가장 많았습니다 .   이를 바탕 으로 헬멧 여부 에 대한 자료 를 조사 해보았습니다 .   교통사고 사망자 내 헬멧 착용 여부 비율 을 보니 헬멧 을 쓰지 않은 사람 의 사망률 이 높은 것 을 확인 하였습니다 .     추가 로 서울 기준 요일 , 시간 대별 이륜차 사 고수 를 조사 해보았습니다 .   4년 간 빠지지 않고 금 , 토 가 가장 많은 사고 가 일어났고 18시 에서 20시 사이 에 가장 많은 사고 가 일어났 습 니 디 .     다음 은 서울 을 기준 으로 이륜차 사고 가 가장 많이 일어나는 지역 과 구역 을 히트맵 과 포리 움 으로 구현 해보았습니다 .     다음 은 앞서 정제 한 데이터 를 바탕 으로 다양한 검증 및 분석 을 진행 해보았습니다 .   먼저 헬멧 여부 와 사망 자율 에 대해 t - 검정 을 해보았습니다 .   귀무가설 을 헬멧 을 착용 하면 사망 가능성 이 늘어난다로 두었고 결과 p - value 가 0.002 로 0.05 보다 낮으므로 귀무가설 이 기각 되고 헬멧 이 사망 에 연관 이 있고 미착 용시 사망 가능성 이 높다고 볼 수 있습니다 .     다음 은 년도 별 이륜차 등록 수 와 사고건 수 를 t - 검정 과 상관관계 를 진행 해보았습니다 . p - value 가 0.05 보다 낮으므로 이륜차 등록 수 와 사고건 수 는 관계 가 있는 것 으로 확인 하였고 상관관계 분석 을 통해 같이 증가 하는 것 을 알 수 있습니다 .     앞선 두 요소 에 배달 종사 자수 를 함께 분석 해보았더니 다음 과 같은 결과 가 나왔습니다 . 히트맵 을 보시 면 이륜차 등록 수 와 사고건 수 는 0.65 , 종사 자수 와 사고건 수 는 0.63 의 상관 계수 가 나왔지만 분석 결과 가 아쉬어 이전 에 진행 한 월 별로 분석 을 재 진행 해보았습니다 .     먼저 월별 등록 대수 와 사고 율 을 상관관계 와 회귀분석 을 진행 하였고 양 의 상관관계 를 보이 며 회귀분석 결과 는 다음 과 같습니다 . >     다음 은 월별 온라인 판매량 과 사고 율 을 상관관계 와 회귀분석 을 진행 하였고 양 의 상관관계 를 보이 며 0.72 의 높은 상관 계수 를 보이 고 있습니다 . 회귀분석 결과 는 다음 과 같습니다 . >           월별 등록 대수 와 온라인 판매량 역시 같은 양 의 상관관계 와 0.83 의 높은 상관 계수 를 보이 며 회귀분석 결과 는 다음 과 같습니다 .   >       앞선 세 가지 요소 가 거의 모두 양 의 상관관계 를 보이 고 있고 특히 이륜차 등록 대수 와 온라인 판매량 의 상관 계 수도 는 0.83 으로 큰 관계성 을 보인다 .   사고 율과 온라인 판매량 , 사고 율과 이륜차 등록 대수 역시 0.7 이상 으로 큰 관계성 을 보이 고 있다 .     다음 은 강수량 과 사고 의 관련성 을 알아보고싶어 추가 로 분석 을 진행 해보았습니다 .   지역 을 서울 과 부산 으로 나누어 조사 하였습니다 .   먼저 서울 의 결과 입니다 . 서울 은 강수량 과 사고건 수가 비슷한 그래프 를 그리고 있습니다 . t - 검정 을 해보니 p - value 가 0.05 보다 낮은 값 을 보입니다 . 상관관계 를 분석 해보니 산점도 가 많이 퍼져있지만 그래도 양 의 그래프 를 그리고 있습니다 . 상관 계 수도 역시 0.59 로 높은 수치 를 보이 지는 않으나 아예 관계 가 없어 보이 지는 않습니다 .     부산 의 결과 입니다 .   부산 은 꺾은선 그래프 만 봐도 강수량 과 사고건 수가 전혀 다른 추세 를 보이 고 있 음 을 알 수 있습니다 .   검정 결과 역시 p - value 가 0.365 로 0.05 보다 훨씬 높은 값 이 나왔다 .   부산 과 서울 을 비교 해보았을 때 비교 적 서울 이 부산 보다 강수량 과 사고건 수가 연관 이 있다고 볼 수 는 있으나 21년 만의 자료 이기 때문 에 이 전 년도 의 강수량 과 사고건 수의 관계 까지 연관 이 있다고 말 하기는 조금 무리 가 있다고 생각 합니다 .     결과 입니다 .   배달 종사 자 와 온라인 매출 은 꾸준히 증가 하나 이륜차 등록 수 와 사고건 수 는 21년 기준 약간 감소 하였으나 두 요소 가 같이 움직임 을 보이 고 진행 한 검정 , 분석 결과 를 바탕 으로 이륜차 수 와 사고 는 관계 가 있다고 보입니다 .   또한 헬멧 착용 이 사망 과 관련 이 있으므로 이륜차 이용 시 꼭 안전 보호 장구 를 착용 하여야 합니다 .     마지막 으로 django 를 보여 드리고 발표 끝내겠습니다 .   '

# %%
from collections import Counter
Counter(new_txt).most_common()
# Out:
# [('', 144),
#  ('.', 59),
#  ('를', 42),
#  ('을', 37),
#  ('이륜차', 30),
#  ('가', 25),
#  ('사고', 23),
#  ('수', 22),
#  ('와', 22),
#  ('이', 20),
#  ('과', 19),
#  ('의', 19),
#  ('는', 18),
#  ('에', 17),
#  ('등록', 15),
#  ('으로', 14),
#  ('보이', 14),
#  ('다음', 13),
#  ('은', 13),
#  ('결과', 12),
#  ('배달', 12),
#  ('사고건', 12),
#  ('증가', 11),
#  ('온라인', 11),
#  ('있습니다', 11),
#  ('분석', 10),
#  ('고', 10),
#  ('진행', 9),
#  ('하였습니다', 9),
#  (',', 9),
#  ('데이터', 9),
#  ('대수', 9),
#  ('조사', 9),
#  ('것', 9),
#  ('판매량', 9),
#  ('상관관계', 9),
#  ('한', 8),
#  ('해보았습니다', 8),
#  ('로', 7),
#  ('입니다', 7),
#  ('그래프', 7),
#  ('21년', 7),
#  ('보다', 7),
#  ('헬멧', 7),
#  ('서울', 7),
#  ('-', 7),
#  ('같습니다', 6),
#  ('확인', 6),
#  ('역시', 6),
#  ('종사', 6),
#  ('하는', 5),
#  ('율', 5),
#  ('가장', 5),
#  ('해보니', 5),
#  ('자수', 5),
#  ('높은', 5),
#  ('사망', 5),
#  ('검정', 5),
#  ('상관', 5),
#  ('회귀분석', 5),
#  ('양', 5),
#  ('강수량', 5),
#  ('부산', 5),
#  ('및', 4),
#  ('많은', 4),
#  ('관련', 4),
#  ('먼저', 4),
#  ('에서', 4),
#  ('모두', 4),
#  ('감소', 4),
#  ('월별', 4),
#  ('별로', 4),
#  ('하였고', 4),
#  ('수가', 4),
#  ('착용', 4),
#  ('p', 4),
#  ('value', 4),
#  ('0.05', 4),
#  ('관계', 4),
#  ('있다고', 4),
#  ('발표', 3),
#  ('저희', 3),
#  ('대해', 3),
#  ('대한', 3),
#  ('제공', 3),
#  ('합니다', 3),
#  ('중', 3),
#  ('기사', 3),
#  ('아마', 3),
#  ('원', 3),
#  ('사람', 3),
#  ('교통사고', 3),
#  ('현황', 3),
#  ('추세', 3),
#  ('까지', 3),
#  ('알', 3),
#  ('있고', 3),
#  ('자', 3),
#  ('수치', 3),
#  ('사', 3),
#  ('년도', 3),
#  ('월', 3),
#  ('위반', 3),
#  ('바탕', 3),
#  ('여부', 3),
#  ('기준', 3),
#  ('t', 3),
#  ('연관', 3),
#  ('요소', 3),
#  ('계수', 3),
#  ('며', 3),
#  ('>', 3),
#  ('하고', 2),
#  ('정보', 2),
#  ('수집', 2),
#  ('마지막', 2),
#  ('보여', 2),
#  ('이유', 2),
#  ('늘', 2),
#  ('또한', 2),
#  ('생각', 2),
#  ('하여', 2),
#  ('들', 2),
#  ('이를', 2),
#  ('구현', 2),
#  ('하게', 2),
#  ('되었습니다', 2),
#  ('설명', 2),
#  ('전국', 2),
#  ('전', 2),
#  ('할', 2),
#  ('때', 2),
#  ('매출', 2),
#  ('계속', 2),
#  ('부터', 2),
#  ('불법', 2),
#  ('단속', 2),
#  ('영향', 2),
#  ('받은', 2),
#  ('전체', 2),
#  ('차지', 2),
#  ('18년', 2),
#  ('부상', 2),
#  ('함께', 2),
#  ('비슷한', 2),
#  ('사망자', 2),
#  ('꾸준히', 2),
#  ('고수', 2),
#  ('조금', 2),
#  ('이전', 2),
#  ('없어', 2),
#  ('있는', 2),
#  ('법규', 2),
#  ('보호', 2),
#  ('미착', 2),
#  ('자료', 2),
#  ('추가', 2),
#  ('많이', 2),
#  ('지역', 2),
#  ('히트맵', 2),
#  ('귀무가설', 2),
#  ('가능성', 2),
#  ('낮으므로', 2),
#  ('볼', 2),
#  ('같이', 2),
#  ('앞선', 2),
#  ('두', 2),
#  ('같은', 2),
#  ('0.83', 2),
#  ('계', 2),
#  ('수도', 2),
#  ('큰', 2),
#  ('관계성', 2),
#  ('율과', 2),
#  ('그리고', 2),
#  ('값', 2),
#  ('보입니다', 2),
#  ('지는', 2),
#  ('비교', 2),
#  ('문', 1),
#  ('안녕하세요', 1),
#  ('그', 1),
#  ('프로젝트', 1),
#  ('순서', 1),
#  ('개요', 1),
#  ('장고', 1),
#  ('드리며', 1),
#  ('마무리', 1),
#  ('하려', 1),
#  ('선택', 1),
#  ('코로나', 1),
#  ('이후', 1),
#  ('수요', 1),
#  ('했고', 1),
#  ('율도', 1),
#  ('하였다는', 1),
#  ('접', 1),
#  ('여기', 1),
#  ('서', 1),
#  ('음식', 1),
#  ('늘면서', 1),
#  ('그로', 1),
#  ('인해', 1),
#  ('지', 1),
#  ('않았을까', 1),
#  ('라고', 1),
#  ('그래서', 1),
#  ('있는지', 1),
#  ('궁금하였고', 1),
#  ('또', 1),
#  ('운전자', 1),
#  ('또는', 1),
#  ('궁금해하는', 1),
#  ('에게', 1),
#  ('해주는', 1),
#  ('웹', 1),
#  ('해보면', 1),
#  ('좋을', 1),
#  ('같아', 1),
#  ('주제', 1),
#  ('선정', 1),
#  ('바로', 1),
#  ('해드리겠습니다', 1),
#  ('증감', 1),
#  ('률', 1),
#  ('대부분', 1),
#  ('유료', 1),
#  ('되어', 1),
#  ('작성', 1),
#  ('참고', 1),
#  ('해당', 1),
#  ('사용', 1),
#  ('보면', 1),
#  ('도', 1),
#  ('17년', 1),
#  ('20년', 1),
#  ('해서', 1),
#  ('하다', 1),
#  ('원인', 1),
#  ('인한', 1),
#  ('일어난', 1),
#  ('31%', 1),
#  ('왼쪽', 1),
#  ('오른쪽', 1),
#  ('모아', 1),
#  ('그려', 1),
#  ('보았습니다', 1),
#  ('반면', 1),
#  ('하다가', 1),
#  ('이는', 1),
#  ('말씀드린', 1),
#  ('앞', 1),
#  ('더', 1),
#  ('정확한', 1),
#  ('수지', 1),
#  ('보고싶어', 1),
#  ('되는', 1),
#  ('대체', 1),
#  ('상승', 1),
#  ('고유', 1),
#  ('형', 1),
#  ('대', 1),
#  ('단독', 1),
#  ('눈', 1),
#  ('띄게', 1),
#  ('건수', 1),
#  ('이어', 1),
#  ('사례', 1),
#  ('알아보겠습니다', 1),
#  ('신호', 1),
#  ('장', 1),
#  ('구', 1),
#  ('용건', 1),
#  ('많았습니다', 1),
#  ('내', 1),
#  ('비율', 1),
#  ('보니', 1),
#  ('쓰지', 1),
#  ('않은', 1),
#  ('사망률', 1),
#  ('요일', 1),
#  ('시간', 1),
#  ('대별', 1),
#  ('4년', 1),
#  ('간', 1),
#  ('빠지지', 1),
#  ('않고', 1),
#  ('금', 1),
#  ('토', 1),
#  ('일어났고', 1),
#  ('18시', 1),
#  ('20시', 1),
#  ('사이', 1),
#  ('일어났', 1),
#  ('습', 1),
#  ('니', 1),
#  ('디', 1),
#  ('일어나는', 1),
#  ('구역', 1),
#  ('포리', 1),
#  ('움', 1),
#  ('앞서', 1),
#  ('정제', 1),
#  ('다양한', 1),
#  ('검증', 1),
#  ('자율', 1),
#  ('하면', 1),
#  ('늘어난다로', 1),
#  ('두었고', 1),
#  ('0.002', 1),
#  ('기각', 1),
#  ('되고', 1),
#  ('용시', 1),
#  ('높다고', 1),
#  ('별', 1),
#  ('통해', 1),
#  ('해보았더니', 1),
#  ('나왔습니다', 1),
#  ('보시', 1),
#  ('면', 1),
#  ('0.65', 1),
#  ('0.63', 1),
#  ('나왔지만', 1),
#  ('아쉬어', 1),
#  ('재', 1),
#  ('0.72', 1),
#  ('세', 1),
#  ('가지', 1),
#  ('거의', 1),
#  ('특히', 1),
#  ('보인다', 1),
#  ('0.7', 1),
#  ('이상', 1),
#  ('있다', 1),
#  ('관련성', 1),
#  ('알아보고싶어', 1),
#  ('나누어', 1),
#  ('낮은', 1),
#  ('산점도', 1),
#  ('퍼져있지만', 1),
#  ('그래도', 1),
#  ('0.59', 1),
#  ('않으나', 1),
#  ('아예', 1),
#  ('않습니다', 1),
#  ('꺾은선', 1),
#  ('만', 1),
#  ('봐도', 1),
#  ('전혀', 1),
#  ('다른', 1),
#  ('있', 1),
#  ('음', 1),
#  ('0.365', 1),
#  ('훨씬', 1),
#  ('나왔다', 1),
#  ('해보았을', 1),
#  ('적', 1),
#  ('있으나', 1),
#  ('만의', 1),
#  ('이기', 1),
#  ('때문', 1),
#  ('수의', 1),
#  ('말', 1),
#  ('하기는', 1),
#  ('무리', 1),
#  ('하나', 1),
#  ('약간', 1),
#  ('하였으나', 1),
#  ('움직임', 1),
#  ('있으므로', 1),
#  ('이용', 1),
#  ('시', 1),
#  ('꼭', 1),
#  ('안전', 1),
#  ('장구', 1),
#  ('하여야', 1),
#  ('django', 1),
#  ('드리고', 1),
#  ('끝내겠습니다', 1)]

# %%
# stopwords = 워드클라우드에서 제외할 단어들의 집합

stop = [' ', '.', ',', '-', '을','를','와','의','는','에','으로','은','이','과','고',
       '로','입니다','가','까지']
stopwords = set(stop)

# %%
wc = WordCloud(font_path = 'C:/Windows/Fonts/gulim.ttc',max_words=1000, mask=mask, stopwords=stopwords, margin=10,
               random_state=1, contour_color = 'white').generate(str_txt)

wc.to_file("a_new_hope.png")
plt.axis("off")
plt.figure(figsize = (10,10))
plt.title("Default colors")
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
### 가장 많이 나온 28개 단어 stop에 추가
for i in range(28):
    stop.append(c[i][0])
    
### 여러개 추가 후 꼭 필요한 단어를 stop에서 제회
for i in range(28):
    stop.append(c[i][0])
stop.remove('이건 꼭 있어야 돼')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 ### 가장 많이 나온 28개 단어 stop에 추가
#       2 for i in range(28):
# ----> 3     stop.append(c[i][0])
#       5 ### 여러개 추가 후 꼭 필요한 단어를 stop에서 제회
#       6 for i in range(28):
#
# NameError: name 'c' is not defined

# %%
f = open('./data/대파제육볶음.txt','r', encoding='utf8')
txt = f.readlines()
f.close()

# %%
txt
# Out:
# ["'안녕하세요 백종원입니다 오늘은 지난번 만남의 광장에서 펌프 했던 건데 문의가 되게 많아서 제육볶음인데 그냥 지금이 아니라 대파제육볶음 집어넣자 듬뿍넣고 제품을 알려 드리려고 하는데 사실 이게 포인트는 삼겹살을 이용해서 볶음 할 때 요령 있거든요 좀 알려 드리려고 오늘 겸사겸사해서 알려 드리는 거니까 국내 계신 분들은 사실 제육볶음 잘하는 집에 가면 불만 제대로 나는 제품을 드실 수 있는데 해외에 계신 분들은 집에서 해 먹기도 싶진 않고 우리 한국에서 못 돼서 불만 1시 봅시다', '요거 잘 참고 서해에서 남아 식당에서 더 3시 오실 거예요 그냥 일반 입금하실 때 뒷다리 앞다리 없던 비로 다 가능한데 이거는 삼겹살용 하는 거거든요 근데 비선호부위 가능하면 많이 쓰시고 오늘은 기름기많은 삼겹살 이용하는 걸로 알려 드리는 특별한 방법이니까 참고하셔서 갖고 자세히 가르쳐 드릴게요 일단 삼겹살 있으셔야 돼요 이거는 앞다리 뒷다리 시집가면 앞다리 저 기름이 좀 지방이 많이 두툼하게 붙은걸 갖다 쓰시면 돼요 정말 많이 나와야 되는 거거든요 그거 쓰시면 되고 나머지 재료들은 똑같아요 설탕 고춧가루 간장 모르니까 일단 그럼 깨소금 그다음에 추가로 대파 만약 일반제품의 대파 왜 양파 당근 못 받고 치료 다 들어가겠죠 근데 요거는 대파만 들어가니까 매운 고추 하고 마늘 듬뿍 요새 마늘 마늘 많이 드시고 저를 믿으시고 대파', '대꾸하지 마세요 팔을 이건 또 쉬워요 소설 필요도 반을 이렇게 잘라 준 다음에 적당한 큼직큼직하게 이렇게 이렇게 파마 술 먹는 거 같네요 하면 더 늦어도 돼요 고추도 좀 더 큼직큼직하게 그다음에 마늘을 듬뿍 편으로 수정되고 아니면 귀찮으시면 좀 입금 좀 해 주세요 이렇게 말을 많이 먹어야 돼요 밥도 많이 먹어야 되고 혈액 순환이 아주 좋습니다 그 다음에 삼겹살도 먹기 좋은 크기로 썰어 주세요 근데 조금 이거는 큼직큼직하게 쓰는게 좋습니다 생각보다 더 큰데네 맞습니다 그 다음에 치아가 안 좋으신 분들은 오늘 빼주세요 잘못하면 오돌뼈 때문에 임플란트 해야 돼요 저도 이거 오돌뼈', '치아가 야 이거 삼겹살로 해서 안에 먹다 보면 오돌뼈 씹혀라고 미리 얘기해 주시면 괜찮은데 아무 생각 없이 씹다가 잘못하면 치약 아침이다 그래서 가능하면 오늘 빼고 하세요 준비됐죠 이거는 평상시 조리법을 간다니까 잘 보셔야 돼요 준비해 주시고 여보세요 편해 그냥 두래 붙이기전에 잘 삼겹살을 깔아 주세요 저도 이거 귀찮은 잘 안 해 먹어요 근데 하면 만족도 엄청나지 깔아주시고 불 켜 주세요 삼겹살 구워 주는 거예요 근데 보시고 만약에 하나 달라 팬이 너무 얇거나 불조절을 잘못하시면 너무 세게 안 해요 일부러 너무 센 불에 해버리면 기름이 나오기는 타요 근데', '불을 약하게 해서 저는 이거 이거로 도와주면 주가 편으로 나오거든요 골고루 사하서버 주시는 거야 이렇게 언제까지 기름이 충분히 나와서 자기 기름에 튀겨지도 시작할 때까지 기름 안 났어요 그래서 식용유 감량을 안 해 드리는 거예요 기름이 안 나올 때는 신경을 쓰는 거고 그리고 3가지 삼겹살이라고 하더라도 이렇게 냉장 삼겹살이 경우는 기름이 잘 나오는 아 근데 냉동삼겹살 있을 경우 게임이 잘 안 나와요 그러니까 그 때는 마중 물처럼 기름을 쫙 곳으로 좀 그 기름에 튀겨 주면서 자기 지방이 좀 나와요 여기에 만약에 삼겹살이 집에 갈 수 있는 삼겹살 좀 두껍다 그러면 네가 살짝 합의해서 소금 후추를 이렇게 그러면 기름이 어느 정도 나오고 한쪽 면이 잘 익었다 싶을 때 한번 뒤집어 30분 후에 살짝 아유 맛있게 하셨지요 이럴 때 기술 좋은 사람은 한꺼번에 뒤집을 수 있어요 그렇게 봐서 딱 붙은 거를 거지요', '뒤집어서 다시 다시 잘될 하는 거예요 뒤집은 다음에 그림이 충분히 나왔을 때 마늘 넣어 주세요 돼지고기 기름에 튀겨서 처음부터 드시면 마늘이 밑에 깔려 선반만들기 타요 제가 한번 뒤집은 다음에 그 다음에 시킬 때만 은우 주무세요 자 여기서 이제 고민이 기름을 먹을 것이냐 뺄것이 빼겠습니다 너무 기름이 없어서 맛이 없으니까 김종대 조금만 남겨 놔야지 남았죠 그래 놓고 다시 못가 주는 거야 이제 자 그냥 먹어도 될 정도로 아주 좋지요 미국의 포인트입니다 이거 잘 하셔야 돼 여기서 삼겹살이 노릇노릇 우루루루루 그냥 그냥 바로 소금 찍어서 쌈 싸 먹으면 되겠다 싶을 정도로 많은 남은 기름에 볶아 주면서 포인트에요 이다음에 파는게 아니라 제일 먼저 이렇게만 하면 설탕 설탕을 골고루', '너무 세면 잘못한 감당이 안 돼요 설탕이 들어가면 기름에 설탕이 녹으면서 색깔이 금방 쓰레기 시작해요 겁먹지 마시고 자 보면 설탕갓 압수수색 이름만 남았어 이제 그 다음에 해야 될 일이 간장 간장 잘 못 해이 정도 지금 기름 이쁘기는 한잔 먹었더니 생긴 나 이렇게 엄마 없을 때 해야 돼요 그럼 엄마 이건 얼마나 잘해 준 약 타서 달맞이 많이 들어가는데 못 하면 그냥 기다리세요 이렇게 충분히 들어갔지요이 상태에서 나머지 재료를 간장 지글지글 크고 있죠 필요한게 더 고춧가루 고춧가루 한 가지도 두 가지 골고루 섞어서 자 여기서 이제 문제가 발생하지요 잊어버리면 양념이 잘 안 된다고요 그렇지요 화가 나면 수박 죽어도 안 되지 그러면 쓰기 위해서', '한 거예요 물을 밑에 눌러 주고 나서 그쪽 기름이 놀면 안 돼요 수분이 돌아야지 기름이 너무 싫다는 거야 물을 좀 보내 주면 돼요 근데 물량도 불 집에 있는 불이 너무 쓰지 않으면 물량 조절 하지 왜냐면 생각지도 않게 판에서 물이 다 버려요 그냥 물이 나오면 잘 거니까 신경 쓰지 마시고 그냥 섞어주시면 되고 집에 있는 물이 새 거 내가 이걸 잘해서 수분이 나오기 전에 이미 다 볶아 줬어 그러면 이게 것들도 집에서 양념이 나와서 잘 뭉쳐 지죠 아니면 어떤 이까 그때는 물을 사는 사람들은 잘 빌려 주시면 돼요 마무리는 추가 좀 주시고 그래도 명색이 제육볶음에 참기름 참기름 살짝 안 마실 수 없겠지요', '잘 먹는 사람은 파가 살아 있어야 돼 이런 놓고 계속 괜히 완성 자 한번 먹어 볼까요 이거는 사실 안 먹어 봐도 알 것 같지요 느낌이 갖고 있지요 집에서 잘하시면 이거보다 불만이 더 나을 수도 있어요 일본어 전 조금만 더 있지', '63년생 많이 있어야 돼요 웃기지 좀 마 누르고 말을 싸서 먹고 며칠 전에 남은 술 제육볶음에 쌈 싸 먹는게 제일 싸 먹는다 해 보세요 받으실 거예요 맛있게 드세요'"]

# %%
# 줄바꾸기 지우기
new_txt = []
for i in txt:
    new_txt.append(i.replace("'",''))

# %%
new_txt
# Out:
# ['안녕하세요 백종원입니다 오늘은 지난번 만남의 광장에서 펌프 했던 건데 문의가 되게 많아서 제육볶음인데 그냥 지금이 아니라 대파제육볶음 집어넣자 듬뿍넣고 제품을 알려 드리려고 하는데 사실 이게 포인트는 삼겹살을 이용해서 볶음 할 때 요령 있거든요 좀 알려 드리려고 오늘 겸사겸사해서 알려 드리는 거니까 국내 계신 분들은 사실 제육볶음 잘하는 집에 가면 불만 제대로 나는 제품을 드실 수 있는데 해외에 계신 분들은 집에서 해 먹기도 싶진 않고 우리 한국에서 못 돼서 불만 1시 봅시다, 요거 잘 참고 서해에서 남아 식당에서 더 3시 오실 거예요 그냥 일반 입금하실 때 뒷다리 앞다리 없던 비로 다 가능한데 이거는 삼겹살용 하는 거거든요 근데 비선호부위 가능하면 많이 쓰시고 오늘은 기름기많은 삼겹살 이용하는 걸로 알려 드리는 특별한 방법이니까 참고하셔서 갖고 자세히 가르쳐 드릴게요 일단 삼겹살 있으셔야 돼요 이거는 앞다리 뒷다리 시집가면 앞다리 저 기름이 좀 지방이 많이 두툼하게 붙은걸 갖다 쓰시면 돼요 정말 많이 나와야 되는 거거든요 그거 쓰시면 되고 나머지 재료들은 똑같아요 설탕 고춧가루 간장 모르니까 일단 그럼 깨소금 그다음에 추가로 대파 만약 일반제품의 대파 왜 양파 당근 못 받고 치료 다 들어가겠죠 근데 요거는 대파만 들어가니까 매운 고추 하고 마늘 듬뿍 요새 마늘 마늘 많이 드시고 저를 믿으시고 대파, 대꾸하지 마세요 팔을 이건 또 쉬워요 소설 필요도 반을 이렇게 잘라 준 다음에 적당한 큼직큼직하게 이렇게 이렇게 파마 술 먹는 거 같네요 하면 더 늦어도 돼요 고추도 좀 더 큼직큼직하게 그다음에 마늘을 듬뿍 편으로 수정되고 아니면 귀찮으시면 좀 입금 좀 해 주세요 이렇게 말을 많이 먹어야 돼요 밥도 많이 먹어야 되고 혈액 순환이 아주 좋습니다 그 다음에 삼겹살도 먹기 좋은 크기로 썰어 주세요 근데 조금 이거는 큼직큼직하게 쓰는게 좋습니다 생각보다 더 큰데네 맞습니다 그 다음에 치아가 안 좋으신 분들은 오늘 빼주세요 잘못하면 오돌뼈 때문에 임플란트 해야 돼요 저도 이거 오돌뼈, 치아가 야 이거 삼겹살로 해서 안에 먹다 보면 오돌뼈 씹혀라고 미리 얘기해 주시면 괜찮은데 아무 생각 없이 씹다가 잘못하면 치약 아침이다 그래서 가능하면 오늘 빼고 하세요 준비됐죠 이거는 평상시 조리법을 간다니까 잘 보셔야 돼요 준비해 주시고 여보세요 편해 그냥 두래 붙이기전에 잘 삼겹살을 깔아 주세요 저도 이거 귀찮은 잘 안 해 먹어요 근데 하면 만족도 엄청나지 깔아주시고 불 켜 주세요 삼겹살 구워 주는 거예요 근데 보시고 만약에 하나 달라 팬이 너무 얇거나 불조절을 잘못하시면 너무 세게 안 해요 일부러 너무 센 불에 해버리면 기름이 나오기는 타요 근데, 불을 약하게 해서 저는 이거 이거로 도와주면 주가 편으로 나오거든요 골고루 사하서버 주시는 거야 이렇게 언제까지 기름이 충분히 나와서 자기 기름에 튀겨지도 시작할 때까지 기름 안 났어요 그래서 식용유 감량을 안 해 드리는 거예요 기름이 안 나올 때는 신경을 쓰는 거고 그리고 3가지 삼겹살이라고 하더라도 이렇게 냉장 삼겹살이 경우는 기름이 잘 나오는 아 근데 냉동삼겹살 있을 경우 게임이 잘 안 나와요 그러니까 그 때는 마중 물처럼 기름을 쫙 곳으로 좀 그 기름에 튀겨 주면서 자기 지방이 좀 나와요 여기에 만약에 삼겹살이 집에 갈 수 있는 삼겹살 좀 두껍다 그러면 네가 살짝 합의해서 소금 후추를 이렇게 그러면 기름이 어느 정도 나오고 한쪽 면이 잘 익었다 싶을 때 한번 뒤집어 30분 후에 살짝 아유 맛있게 하셨지요 이럴 때 기술 좋은 사람은 한꺼번에 뒤집을 수 있어요 그렇게 봐서 딱 붙은 거를 거지요, 뒤집어서 다시 다시 잘될 하는 거예요 뒤집은 다음에 그림이 충분히 나왔을 때 마늘 넣어 주세요 돼지고기 기름에 튀겨서 처음부터 드시면 마늘이 밑에 깔려 선반만들기 타요 제가 한번 뒤집은 다음에 그 다음에 시킬 때만 은우 주무세요 자 여기서 이제 고민이 기름을 먹을 것이냐 뺄것이 빼겠습니다 너무 기름이 없어서 맛이 없으니까 김종대 조금만 남겨 놔야지 남았죠 그래 놓고 다시 못가 주는 거야 이제 자 그냥 먹어도 될 정도로 아주 좋지요 미국의 포인트입니다 이거 잘 하셔야 돼 여기서 삼겹살이 노릇노릇 우루루루루 그냥 그냥 바로 소금 찍어서 쌈 싸 먹으면 되겠다 싶을 정도로 많은 남은 기름에 볶아 주면서 포인트에요 이다음에 파는게 아니라 제일 먼저 이렇게만 하면 설탕 설탕을 골고루, 너무 세면 잘못한 감당이 안 돼요 설탕이 들어가면 기름에 설탕이 녹으면서 색깔이 금방 쓰레기 시작해요 겁먹지 마시고 자 보면 설탕갓 압수수색 이름만 남았어 이제 그 다음에 해야 될 일이 간장 간장 잘 못 해이 정도 지금 기름 이쁘기는 한잔 먹었더니 생긴 나 이렇게 엄마 없을 때 해야 돼요 그럼 엄마 이건 얼마나 잘해 준 약 타서 달맞이 많이 들어가는데 못 하면 그냥 기다리세요 이렇게 충분히 들어갔지요이 상태에서 나머지 재료를 간장 지글지글 크고 있죠 필요한게 더 고춧가루 고춧가루 한 가지도 두 가지 골고루 섞어서 자 여기서 이제 문제가 발생하지요 잊어버리면 양념이 잘 안 된다고요 그렇지요 화가 나면 수박 죽어도 안 되지 그러면 쓰기 위해서, 한 거예요 물을 밑에 눌러 주고 나서 그쪽 기름이 놀면 안 돼요 수분이 돌아야지 기름이 너무 싫다는 거야 물을 좀 보내 주면 돼요 근데 물량도 불 집에 있는 불이 너무 쓰지 않으면 물량 조절 하지 왜냐면 생각지도 않게 판에서 물이 다 버려요 그냥 물이 나오면 잘 거니까 신경 쓰지 마시고 그냥 섞어주시면 되고 집에 있는 물이 새 거 내가 이걸 잘해서 수분이 나오기 전에 이미 다 볶아 줬어 그러면 이게 것들도 집에서 양념이 나와서 잘 뭉쳐 지죠 아니면 어떤 이까 그때는 물을 사는 사람들은 잘 빌려 주시면 돼요 마무리는 추가 좀 주시고 그래도 명색이 제육볶음에 참기름 참기름 살짝 안 마실 수 없겠지요, 잘 먹는 사람은 파가 살아 있어야 돼 이런 놓고 계속 괜히 완성 자 한번 먹어 볼까요 이거는 사실 안 먹어 봐도 알 것 같지요 느낌이 갖고 있지요 집에서 잘하시면 이거보다 불만이 더 나을 수도 있어요 일본어 전 조금만 더 있지, 63년생 많이 있어야 돼요 웃기지 좀 마 누르고 말을 싸서 먹고 며칠 전에 남은 술 제육볶음에 쌈 싸 먹는게 제일 싸 먹는다 해 보세요 받으실 거예요 맛있게 드세요']

# %%
from collections import Counter
Counter(new_txt).most_common()
# Out:
# [('안녕하세요 백종원입니다 오늘은 지난번 만남의 광장에서 펌프 했던 건데 문의가 되게 많아서 제육볶음인데 그냥 지금이 아니라 대파제육볶음 집어넣자 듬뿍넣고 제품을 알려 드리려고 하는데 사실 이게 포인트는 삼겹살을 이용해서 볶음 할 때 요령 있거든요 좀 알려 드리려고 오늘 겸사겸사해서 알려 드리는 거니까 국내 계신 분들은 사실 제육볶음 잘하는 집에 가면 불만 제대로 나는 제품을 드실 수 있는데 해외에 계신 분들은 집에서 해 먹기도 싶진 않고 우리 한국에서 못 돼서 불만 1시 봅시다, 요거 잘 참고 서해에서 남아 식당에서 더 3시 오실 거예요 그냥 일반 입금하실 때 뒷다리 앞다리 없던 비로 다 가능한데 이거는 삼겹살용 하는 거거든요 근데 비선호부위 가능하면 많이 쓰시고 오늘은 기름기많은 삼겹살 이용하는 걸로 알려 드리는 특별한 방법이니까 참고하셔서 갖고 자세히 가르쳐 드릴게요 일단 삼겹살 있으셔야 돼요 이거는 앞다리 뒷다리 시집가면 앞다리 저 기름이 좀 지방이 많이 두툼하게 붙은걸 갖다 쓰시면 돼요 정말 많이 나와야 되는 거거든요 그거 쓰시면 되고 나머지 재료들은 똑같아요 설탕 고춧가루 간장 모르니까 일단 그럼 깨소금 그다음에 추가로 대파 만약 일반제품의 대파 왜 양파 당근 못 받고 치료 다 들어가겠죠 근데 요거는 대파만 들어가니까 매운 고추 하고 마늘 듬뿍 요새 마늘 마늘 많이 드시고 저를 믿으시고 대파, 대꾸하지 마세요 팔을 이건 또 쉬워요 소설 필요도 반을 이렇게 잘라 준 다음에 적당한 큼직큼직하게 이렇게 이렇게 파마 술 먹는 거 같네요 하면 더 늦어도 돼요 고추도 좀 더 큼직큼직하게 그다음에 마늘을 듬뿍 편으로 수정되고 아니면 귀찮으시면 좀 입금 좀 해 주세요 이렇게 말을 많이 먹어야 돼요 밥도 많이 먹어야 되고 혈액 순환이 아주 좋습니다 그 다음에 삼겹살도 먹기 좋은 크기로 썰어 주세요 근데 조금 이거는 큼직큼직하게 쓰는게 좋습니다 생각보다 더 큰데네 맞습니다 그 다음에 치아가 안 좋으신 분들은 오늘 빼주세요 잘못하면 오돌뼈 때문에 임플란트 해야 돼요 저도 이거 오돌뼈, 치아가 야 이거 삼겹살로 해서 안에 먹다 보면 오돌뼈 씹혀라고 미리 얘기해 주시면 괜찮은데 아무 생각 없이 씹다가 잘못하면 치약 아침이다 그래서 가능하면 오늘 빼고 하세요 준비됐죠 이거는 평상시 조리법을 간다니까 잘 보셔야 돼요 준비해 주시고 여보세요 편해 그냥 두래 붙이기전에 잘 삼겹살을 깔아 주세요 저도 이거 귀찮은 잘 안 해 먹어요 근데 하면 만족도 엄청나지 깔아주시고 불 켜 주세요 삼겹살 구워 주는 거예요 근데 보시고 만약에 하나 달라 팬이 너무 얇거나 불조절을 잘못하시면 너무 세게 안 해요 일부러 너무 센 불에 해버리면 기름이 나오기는 타요 근데, 불을 약하게 해서 저는 이거 이거로 도와주면 주가 편으로 나오거든요 골고루 사하서버 주시는 거야 이렇게 언제까지 기름이 충분히 나와서 자기 기름에 튀겨지도 시작할 때까지 기름 안 났어요 그래서 식용유 감량을 안 해 드리는 거예요 기름이 안 나올 때는 신경을 쓰는 거고 그리고 3가지 삼겹살이라고 하더라도 이렇게 냉장 삼겹살이 경우는 기름이 잘 나오는 아 근데 냉동삼겹살 있을 경우 게임이 잘 안 나와요 그러니까 그 때는 마중 물처럼 기름을 쫙 곳으로 좀 그 기름에 튀겨 주면서 자기 지방이 좀 나와요 여기에 만약에 삼겹살이 집에 갈 수 있는 삼겹살 좀 두껍다 그러면 네가 살짝 합의해서 소금 후추를 이렇게 그러면 기름이 어느 정도 나오고 한쪽 면이 잘 익었다 싶을 때 한번 뒤집어 30분 후에 살짝 아유 맛있게 하셨지요 이럴 때 기술 좋은 사람은 한꺼번에 뒤집을 수 있어요 그렇게 봐서 딱 붙은 거를 거지요, 뒤집어서 다시 다시 잘될 하는 거예요 뒤집은 다음에 그림이 충분히 나왔을 때 마늘 넣어 주세요 돼지고기 기름에 튀겨서 처음부터 드시면 마늘이 밑에 깔려 선반만들기 타요 제가 한번 뒤집은 다음에 그 다음에 시킬 때만 은우 주무세요 자 여기서 이제 고민이 기름을 먹을 것이냐 뺄것이 빼겠습니다 너무 기름이 없어서 맛이 없으니까 김종대 조금만 남겨 놔야지 남았죠 그래 놓고 다시 못가 주는 거야 이제 자 그냥 먹어도 될 정도로 아주 좋지요 미국의 포인트입니다 이거 잘 하셔야 돼 여기서 삼겹살이 노릇노릇 우루루루루 그냥 그냥 바로 소금 찍어서 쌈 싸 먹으면 되겠다 싶을 정도로 많은 남은 기름에 볶아 주면서 포인트에요 이다음에 파는게 아니라 제일 먼저 이렇게만 하면 설탕 설탕을 골고루, 너무 세면 잘못한 감당이 안 돼요 설탕이 들어가면 기름에 설탕이 녹으면서 색깔이 금방 쓰레기 시작해요 겁먹지 마시고 자 보면 설탕갓 압수수색 이름만 남았어 이제 그 다음에 해야 될 일이 간장 간장 잘 못 해이 정도 지금 기름 이쁘기는 한잔 먹었더니 생긴 나 이렇게 엄마 없을 때 해야 돼요 그럼 엄마 이건 얼마나 잘해 준 약 타서 달맞이 많이 들어가는데 못 하면 그냥 기다리세요 이렇게 충분히 들어갔지요이 상태에서 나머지 재료를 간장 지글지글 크고 있죠 필요한게 더 고춧가루 고춧가루 한 가지도 두 가지 골고루 섞어서 자 여기서 이제 문제가 발생하지요 잊어버리면 양념이 잘 안 된다고요 그렇지요 화가 나면 수박 죽어도 안 되지 그러면 쓰기 위해서, 한 거예요 물을 밑에 눌러 주고 나서 그쪽 기름이 놀면 안 돼요 수분이 돌아야지 기름이 너무 싫다는 거야 물을 좀 보내 주면 돼요 근데 물량도 불 집에 있는 불이 너무 쓰지 않으면 물량 조절 하지 왜냐면 생각지도 않게 판에서 물이 다 버려요 그냥 물이 나오면 잘 거니까 신경 쓰지 마시고 그냥 섞어주시면 되고 집에 있는 물이 새 거 내가 이걸 잘해서 수분이 나오기 전에 이미 다 볶아 줬어 그러면 이게 것들도 집에서 양념이 나와서 잘 뭉쳐 지죠 아니면 어떤 이까 그때는 물을 사는 사람들은 잘 빌려 주시면 돼요 마무리는 추가 좀 주시고 그래도 명색이 제육볶음에 참기름 참기름 살짝 안 마실 수 없겠지요, 잘 먹는 사람은 파가 살아 있어야 돼 이런 놓고 계속 괜히 완성 자 한번 먹어 볼까요 이거는 사실 안 먹어 봐도 알 것 같지요 느낌이 갖고 있지요 집에서 잘하시면 이거보다 불만이 더 나을 수도 있어요 일본어 전 조금만 더 있지, 63년생 많이 있어야 돼요 웃기지 좀 마 누르고 말을 싸서 먹고 며칠 전에 남은 술 제육볶음에 쌈 싸 먹는게 제일 싸 먹는다 해 보세요 받으실 거예요 맛있게 드세요',
#   1)]

# %%
str_txt = ''
for i in new_txt:
    str_txt = str_txt + i + ' '

# %%
str_txt
# Out:
# "'안녕하세요 백종원입니다 오늘은 지난번 만남의 광장에서 펌프 했던 건데 문의가 되게 많아서 제육볶음인데 그냥 지금이 아니라 대파제육볶음 집어넣자 듬뿍넣고 제품을 알려 드리려고 하는데 사실 이게 포인트는 삼겹살을 이용해서 볶음 할 때 요령 있거든요 좀 알려 드리려고 오늘 겸사겸사해서 알려 드리는 거니까 국내 계신 분들은 사실 제육볶음 잘하는 집에 가면 불만 제대로 나는 제품을 드실 수 있는데 해외에 계신 분들은 집에서 해 먹기도 싶진 않고 우리 한국에서 못 돼서 불만 1시 봅시다', '요거 잘 참고 서해에서 남아 식당에서 더 3시 오실 거예요 그냥 일반 입금하실 때 뒷다리 앞다리 없던 비로 다 가능한데 이거는 삼겹살용 하는 거거든요 근데 비선호부위 가능하면 많이 쓰시고 오늘은 기름기많은 삼겹살 이용하는 걸로 알려 드리는 특별한 방법이니까 참고하셔서 갖고 자세히 가르쳐 드릴게요 일단 삼겹살 있으셔야 돼요 이거는 앞다리 뒷다리 시집가면 앞다리 저 기름이 좀 지방이 많이 두툼하게 붙은걸 갖다 쓰시면 돼요 정말 많이 나와야 되는 거거든요 그거 쓰시면 되고 나머지 재료들은 똑같아요 설탕 고춧가루 간장 모르니까 일단 그럼 깨소금 그다음에 추가로 대파 만약 일반제품의 대파 왜 양파 당근 못 받고 치료 다 들어가겠죠 근데 요거는 대파만 들어가니까 매운 고추 하고 마늘 듬뿍 요새 마늘 마늘 많이 드시고 저를 믿으시고 대파', '대꾸하지 마세요 팔을 이건 또 쉬워요 소설 필요도 반을 이렇게 잘라 준 다음에 적당한 큼직큼직하게 이렇게 이렇게 파마 술 먹는 거 같네요 하면 더 늦어도 돼요 고추도 좀 더 큼직큼직하게 그다음에 마늘을 듬뿍 편으로 수정되고 아니면 귀찮으시면 좀 입금 좀 해 주세요 이렇게 말을 많이 먹어야 돼요 밥도 많이 먹어야 되고 혈액 순환이 아주 좋습니다 그 다음에 삼겹살도 먹기 좋은 크기로 썰어 주세요 근데 조금 이거는 큼직큼직하게 쓰는게 좋습니다 생각보다 더 큰데네 맞습니다 그 다음에 치아가 안 좋으신 분들은 오늘 빼주세요 잘못하면 오돌뼈 때문에 임플란트 해야 돼요 저도 이거 오돌뼈', '치아가 야 이거 삼겹살로 해서 안에 먹다 보면 오돌뼈 씹혀라고 미리 얘기해 주시면 괜찮은데 아무 생각 없이 씹다가 잘못하면 치약 아침이다 그래서 가능하면 오늘 빼고 하세요 준비됐죠 이거는 평상시 조리법을 간다니까 잘 보셔야 돼요 준비해 주시고 여보세요 편해 그냥 두래 붙이기전에 잘 삼겹살을 깔아 주세요 저도 이거 귀찮은 잘 안 해 먹어요 근데 하면 만족도 엄청나지 깔아주시고 불 켜 주세요 삼겹살 구워 주는 거예요 근데 보시고 만약에 하나 달라 팬이 너무 얇거나 불조절을 잘못하시면 너무 세게 안 해요 일부러 너무 센 불에 해버리면 기름이 나오기는 타요 근데', '불을 약하게 해서 저는 이거 이거로 도와주면 주가 편으로 나오거든요 골고루 사하서버 주시는 거야 이렇게 언제까지 기름이 충분히 나와서 자기 기름에 튀겨지도 시작할 때까지 기름 안 났어요 그래서 식용유 감량을 안 해 드리는 거예요 기름이 안 나올 때는 신경을 쓰는 거고 그리고 3가지 삼겹살이라고 하더라도 이렇게 냉장 삼겹살이 경우는 기름이 잘 나오는 아 근데 냉동삼겹살 있을 경우 게임이 잘 안 나와요 그러니까 그 때는 마중 물처럼 기름을 쫙 곳으로 좀 그 기름에 튀겨 주면서 자기 지방이 좀 나와요 여기에 만약에 삼겹살이 집에 갈 수 있는 삼겹살 좀 두껍다 그러면 네가 살짝 합의해서 소금 후추를 이렇게 그러면 기름이 어느 정도 나오고 한쪽 면이 잘 익었다 싶을 때 한번 뒤집어 30분 후에 살짝 아유 맛있게 하셨지요 이럴 때 기술 좋은 사람은 한꺼번에 뒤집을 수 있어요 그렇게 봐서 딱 붙은 거를 거지요', '뒤집어서 다시 다시 잘될 하는 거예요 뒤집은 다음에 그림이 충분히 나왔을 때 마늘 넣어 주세요 돼지고기 기름에 튀겨서 처음부터 드시면 마늘이 밑에 깔려 선반만들기 타요 제가 한번 뒤집은 다음에 그 다음에 시킬 때만 은우 주무세요 자 여기서 이제 고민이 기름을 먹을 것이냐 뺄것이 빼겠습니다 너무 기름이 없어서 맛이 없으니까 김종대 조금만 남겨 놔야지 남았죠 그래 놓고 다시 못가 주는 거야 이제 자 그냥 먹어도 될 정도로 아주 좋지요 미국의 포인트입니다 이거 잘 하셔야 돼 여기서 삼겹살이 노릇노릇 우루루루루 그냥 그냥 바로 소금 찍어서 쌈 싸 먹으면 되겠다 싶을 정도로 많은 남은 기름에 볶아 주면서 포인트에요 이다음에 파는게 아니라 제일 먼저 이렇게만 하면 설탕 설탕을 골고루', '너무 세면 잘못한 감당이 안 돼요 설탕이 들어가면 기름에 설탕이 녹으면서 색깔이 금방 쓰레기 시작해요 겁먹지 마시고 자 보면 설탕갓 압수수색 이름만 남았어 이제 그 다음에 해야 될 일이 간장 간장 잘 못 해이 정도 지금 기름 이쁘기는 한잔 먹었더니 생긴 나 이렇게 엄마 없을 때 해야 돼요 그럼 엄마 이건 얼마나 잘해 준 약 타서 달맞이 많이 들어가는데 못 하면 그냥 기다리세요 이렇게 충분히 들어갔지요이 상태에서 나머지 재료를 간장 지글지글 크고 있죠 필요한게 더 고춧가루 고춧가루 한 가지도 두 가지 골고루 섞어서 자 여기서 이제 문제가 발생하지요 잊어버리면 양념이 잘 안 된다고요 그렇지요 화가 나면 수박 죽어도 안 되지 그러면 쓰기 위해서', '한 거예요 물을 밑에 눌러 주고 나서 그쪽 기름이 놀면 안 돼요 수분이 돌아야지 기름이 너무 싫다는 거야 물을 좀 보내 주면 돼요 근데 물량도 불 집에 있는 불이 너무 쓰지 않으면 물량 조절 하지 왜냐면 생각지도 않게 판에서 물이 다 버려요 그냥 물이 나오면 잘 거니까 신경 쓰지 마시고 그냥 섞어주시면 되고 집에 있는 물이 새 거 내가 이걸 잘해서 수분이 나오기 전에 이미 다 볶아 줬어 그러면 이게 것들도 집에서 양념이 나와서 잘 뭉쳐 지죠 아니면 어떤 이까 그때는 물을 사는 사람들은 잘 빌려 주시면 돼요 마무리는 추가 좀 주시고 그래도 명색이 제육볶음에 참기름 참기름 살짝 안 마실 수 없겠지요', '잘 먹는 사람은 파가 살아 있어야 돼 이런 놓고 계속 괜히 완성 자 한번 먹어 볼까요 이거는 사실 안 먹어 봐도 알 것 같지요 느낌이 갖고 있지요 집에서 잘하시면 이거보다 불만이 더 나을 수도 있어요 일본어 전 조금만 더 있지', '63년생 많이 있어야 돼요 웃기지 좀 마 누르고 말을 싸서 먹고 며칠 전에 남은 술 제육볶음에 쌈 싸 먹는게 제일 싸 먹는다 해 보세요 받으실 거예요 맛있게 드세요' "

# %%
wc = WordCloud(font_path = 'C:/Windows/Fonts/gulim.ttc',max_words=1000, mask=mask, stopwords=stopwords, margin=10,
               random_state=1, contour_color = 'white').generate(str_txt)

wc.to_file("a_new_hope.png")
plt.axis("off")
plt.figure(figsize = (10,10))
plt.title("Default colors")
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
def wordcloud(x):
    f = open(x,'r', encoding='utf8')
    txt = f.readlines()
    f.close()
    
    new_txt = []
    for i in txt:
        new_txt.append(i.replace('\n',''))
        
    str_txt = ''
    for i in new_txt:
        str_txt = str_txt + i + ' '
        
    wc = WordCloud(background_color = 'white',font_path = 'C:/Users/admin/AppData/Local/Microsoft/Windows/Fonts/NanumGothicBold.ttf',max_words=1000, mask=mask, stopwords=stopwords, margin=10,
               random_state=1, contour_color = 'black').generate(str_txt)

    wc.to_file("a_new_hope.png")
    plt.axis("off")
    plt.figure(figsize = (10,10))
    plt.title("Default colors")
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    return plt.show()

# %%
wordcloud('./data/morph_1.txt')
